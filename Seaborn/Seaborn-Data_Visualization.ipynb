# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Scatter Plot

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### Plotting it using relplot, catplot

# %% [markdown]
# Relplot = Numerical data plotting, Catplot = Categorical data plotting

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)
plt.show()

# %% [markdown]
# ### Hue, Style and Size

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time', size = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'size')

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'smoker')

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# Controlling the size of these plots

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'size', sizes = (15, 200))

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# ### Line Plot

# %%
from seaborn import relplot

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
df
# Out:
#      time      value
# 0       0  -1.485220
# 1       1  -1.906542
# 2       2  -2.319188
# 3       3  -1.347348
# 4       4   0.950130
# ..    ...        ...
# 495   495 -12.905957
# 496   496 -13.102737
# 497   497 -11.437336
# 498   498 -11.885512
# 499   499 -13.450709
#
# [500 rows x 2 columns]

# %%
relplot(x = 'time', y ='value', kind = 'line', data = df)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#plotting it using line plot
fig, ax = plt.subplots()
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data=fmri)

# %%
#control the size of the plot
relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = False, label = 'Signal', height = 4, aspect = 2)
plt.legend(loc = 'right')
plt.show()

# %%
fmri[fmri['timepoint'] == 5].min()
# Out:
# subject            s0
# timepoint           5
# event             cue
# region        frontal
# signal      -0.017946
# dtype: object

# %%
relplot(x = 'timepoint', y = 'signal', kind = 'line', estimator = None, data = fmri, ci = False, label = 'Signal', height = 4, aspect = 2)
plt.legend(loc = 'right')
plt.show()

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
relplot(x = 'timepoint', y = 'signal', kind = 'line', hue = 'event', data = fmri, ci = False, label = 'Signal', height = 4, aspect = 2)
plt.legend(loc = 'right')
plt.show()

# %%
#plotting multiple signal with various widths and color
# Loading new dataset
dots = sns.load_dataset('dots').query("align == 'dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# Plotting dots variable
relplot(x = 'time', y ='firing_rate', data = dots, kind = "line", ci = False)

# %%
relplot(x = 'time', y ='firing_rate', data = dots, kind = "line",hue = 'coherence', style = 'choice')

# %%
# palette
palette = sns.cubehelix_palette(light = 0.5, n_colors = 6)
relplot(x = 'time', y ='firing_rate', data = dots, kind = "line",hue = 'coherence', style = 'choice', palette= palette)

# %%
# incresing size of the plot style
relplot(x = 'time', y ='firing_rate', data = dots, kind = "line",hue = 'coherence', style = 'choice', size = 'choice')

# %% [markdown]
# ### Subplots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'smoker', data = tips)

# %%
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size',data = tips)

# %%
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time',data = tips, row = 'size')

# %%
# using colwraps
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size',data = tips, col_wrap = 3)

# %% [markdown]
# ### Using sns.lineplot() and scatterplot()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style= 'bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = 'timepoint', y = 'signal', hue = 'event', data = fmri.query("region == 'frontal'"), estimator= None, lw = 1)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ### sns.scatterplot()

# %%
# directly calling scatterplot without relplot
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Categorical data Plotting

# %% [markdown]
# ### cat Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Plotting these categorical value
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
# Horizontal Plotting
sns.catplot(y = 'day', x = 'total_bill', data = tips)

# %%
# switching of jitters 
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %% [markdown]
# ### Swarm Plot

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm', hue = 'size')

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order = ['No', 'Yes'])

# %% [markdown]
# ### Box Plot

# %%
# plotting box plot
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips)

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex')

# %%
# Plotting it in single plot by dodge parameter
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False)

# %% [markdown]
# ### Boxen Plot

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds, hue = 'cut')

# %%
# removing the dodging
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds, hue = 'cut', dodge = False)

# %% [markdown]
# ### violin plot

# %%
sns.catplot(x = 'total_bill', y = 'day', kind = 'violin', data = tips, hue = 'sex', split = True)

# %%
# plotting swarm plot and violin plot together
g = sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm')
sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', data = tips, hue = 'sex', split = True, ax = g.ax)
# Out:
# /home/shouryam/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try violinplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Bar Plot

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# plotting a bar plot
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class')

# %%
# Changing the colors of these bars
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class', palette='ch:0.15')

# %% [markdown]
# ### Point Plot

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'point', hue = 'class', data = titanic)

# %% [markdown]
# ### Joint Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x, y)
# Out:
# /home/shouryam/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x, y, kind= 'hex', color = 'r')
# Out:
# /home/shouryam/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# KDE jointplot
sns.jointplot(x, y, kind= 'kde', color = 'r')
# Out:
# /home/shouryam/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(tips)

# %% [markdown]
# categorical data is discarded in pair plot

# %%
# Doing pairplot and changing these plottings using pairGrid

g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %%
# Plotting in scatter and kde
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
# ### Regression Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# reducing jitters
sns.lmplot(x = 'size', y = 'tip', data = tips)

# %% [markdown]
# ### Controlling Plotted Figure Aesthetics

# %% [markdown]
# ### Sinplot

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sinplot(-1)

# %%
# controlling ticks
sns.set_style('ticks', {'axes.grid': True, 'xticks.direction': 'in'})
sinplot()
sns.despine(left = True, bottom = False)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %% [markdown]
# ### Changing styles of sinplot

# %%
sns.set_style('darkgrid')

# %%
sinplot()
